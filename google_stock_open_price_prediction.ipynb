# %% [markdown]
# ## GOOGLE STOCK OPEN PRICE PREDICTION USING LSTM

# %% [markdown]
# ### 1. Importing the libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20, 10

from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense

from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### 2. Importing the training data set

# %%
train_df = pd.read_csv('dataset/Google_Stock_Price_Train.csv')
train_df.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %% [markdown]
# ### 3. Analyze the opening prices from the training data set

# %%
train_df['Date'] = pd.to_datetime(train_df.Date, format='%m/%d/%Y')
train_df.index = train_df['Date']

plt.figure(figsize=(16,8))
plt.plot(train_df['Open'], label='Open price history')

# %% [markdown]
# ### 4. Sort the dataset on date time and filter "Date" and "Open" columns

# %%
train_data = train_df.sort_index(ascending=True, axis=0)
train_data = train_data.iloc[:, [1]]
train_data.head()
# Out:
#               Open
# Date
# 2012-01-03  325.25
# 2012-01-04  331.27
# 2012-01-05  329.83
# 2012-01-06  328.34
# 2012-01-09  322.04

# %% [markdown]
# ### 5. Normalize the new filtered data set

# %%
train_data_value = train_data.values

scaler = MinMaxScaler(feature_range=(0,1))
train_data_scaled = scaler.fit_transform(train_data_value)

# %% [markdown]
# ### 6. Create a data structure with 60 timesteps and 1 output

# %%
x_train_data, y_train_data = [], []

for i in range(60, len(train_data_scaled)):
    x_train_data.append(train_data_scaled[i-60:i, 0])
    y_train_data.append(train_data_scaled[i, 0])

# %% [markdown]
# ### 7. Data reshaping

# %%
x_train_data, y_train_data = np.array(x_train_data), np.array(y_train_data)

x_train_data = np.reshape(x_train_data, (x_train_data.shape[0], x_train_data.shape[1], 1))

# %% [markdown]
# ### 8. Create the LSTM model

# %%
regressor = Sequential()

# %%
# 1st layer
regressor.add(LSTM(units=50, return_sequences=True, input_shape=(x_train_data.shape[1], 1)))
regressor.add(Dropout(rate = 0.2))

# 2nd, 3rd, 4th layer
for i in range(0, 3):
    regressor.add(LSTM(units=50, return_sequences=True))
    regressor.add(Dropout(rate = 0.2))

# 5th layer
regressor.add(LSTM(units=50, return_sequences=False))
regressor.add(Dropout(rate = 0.2))

# %%
regressor.add(Dense(units=1))

# %%
regressor_large_time_scale = Sequential()

# 1st layer
regressor_large_time_scale.add(LSTM(units=50, return_sequences=True, input_shape=(x_train_data.shape[1], 1)))
regressor_large_time_scale.add(Dropout(rate = 0.2))

# 2nd, 3rd, 4th layer
for i in range(0, 3):
    regressor_large_time_scale.add(LSTM(units=50, return_sequences=True))
    regressor_large_time_scale.add(Dropout(rate = 0.2))

# 5th layer
regressor_large_time_scale.add(LSTM(units=50, return_sequences=False))
regressor_large_time_scale.add(Dropout(rate = 0.2))

regressor_large_time_scale.add(Dense(units=1))

# %% [markdown]
# ### 9. Compile the LSTM model

# %%
regressor.compile(optimizer='adam', loss='mean_squared_error')

# %%
regressor_large_time_scale.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# ### 10. Fit the LSTM model to the training set

# %%
regressor.fit(x_train_data, y_train_data, epochs=100, batch_size=32)
regressor.save('models/google_stock_price_prediction_lstm.h5')
# Out:
# Epoch 1/100
# 38/38 [==============================] - 10s 83ms/step - loss: 0.0487
# Epoch 2/100
# 38/38 [==============================] - 3s 77ms/step - loss: 0.0070
# Epoch 3/100
# 38/38 [==============================] - 3s 79ms/step - loss: 0.0055
# Epoch 4/100
# 38/38 [==============================] - 3s 82ms/step - loss: 0.0051
# Epoch 5/100
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0053
# Epoch 6/100
# 38/38 [==============================] - 3s 75ms/step - loss: 0.0059
# Epoch 7/100
# 38/38 [==============================] - 3s 75ms/step - loss: 0.0048
# Epoch 8/100
# 38/38 [==============================] - 3s 77ms/step - loss: 0.0048
# Epoch 9/100
# 38/38 [==============================] - 3s 78ms/step - loss: 0.0051
# Epoch 10/100
# 38/38 [==============================] - 3s 84ms/step - loss: 0.0067
# Epoch 11/100
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0050
# Epoch 12/100
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0042
# Epoch 13/100
# 38/38 [==============================] - 3s 83ms/step - loss: 0.0041
# Epoch 14/100
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0042
# Epoch 15/100
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0040
# Epoch 16/100
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0042
# Epoch 17/100
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0049
# Epoch 18/100
# 38/38 [==============================] - 3s 81ms/step - loss: 0.0036
# Epoch 19/100
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0042
# Epoch 20/100
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0036
# Epoch 21/100
# 38/38 [==============================] - 3s 82ms/step - loss: 0.0041
# Epoch 22/100
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0039
# Epoch 23/100
# 38/38 [==============================] - 3s 81ms/step - loss: 0.0031
# Epoch 24/100
# 38/38 [==============================] - 3s 73ms/step - loss: 0.0034
# Epoch 25/100
# 38/38 [==============================] - 3s 77ms/step - loss: 0.0035
# Epoch 26/100
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0035
# Epoch 27/100
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0034
# Epoch 28/100
# 38/38 [==============================] - 3s 84ms/step - loss: 0.0032
# Epoch 29/100
# 38/38 [==============================] - 3s 82ms/step - loss: 0.0034
# Epoch 30/100
# 38/38 [==============================] - 3s 78ms/step - loss: 0.0033
# Epoch 31/100
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0032
# Epoch 32/100
# 38/38 [==============================] - 3s 82ms/step - loss: 0.0033
# Epoch 33/100
# 38/38 [==============================] - 3s 83ms/step - loss: 0.0029
# Epoch 34/100
# 38/38 [==============================] - 3s 83ms/step - loss: 0.0032
# Epoch 35/100
# 38/38 [==============================] - 3s 82ms/step - loss: 0.0034
# Epoch 36/100
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0032
# Epoch 37/100
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0029
# Epoch 38/100
# 38/38 [==============================] - 4s 92ms/step - loss: 0.0030
# Epoch 39/100
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0030
# Epoch 40/100
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0028
# Epoch 41/100
# 38/38 [==============================] - 3s 86ms/step - loss: 0.0029
# Epoch 42/100
# 38/38 [==============================] - 3s 82ms/step - loss: 0.0027
# Epoch 43/100
# 38/38 [==============================] - 3s 83ms/step - loss: 0.0027
# Epoch 44/100
# 38/38 [==============================] - 3s 84ms/step - loss: 0.0030
# Epoch 45/100
# 38/38 [==============================] - 3s 84ms/step - loss: 0.0029
# Epoch 46/100
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0031
# Epoch 47/100
# 38/38 [==============================] - 3s 83ms/step - loss: 0.0033
# Epoch 48/100
# 38/38 [==============================] - 3s 79ms/step - loss: 0.0030
# Epoch 49/100
# 38/38 [==============================] - 3s 84ms/step - loss: 0.0027
# Epoch 50/100
# 38/38 [==============================] - 3s 81ms/step - loss: 0.0029
# Epoch 51/100
# 38/38 [==============================] - 3s 79ms/step - loss: 0.0025
# Epoch 52/100
# 38/38 [==============================] - 3s 79ms/step - loss: 0.0026
# Epoch 53/100
# 38/38 [==============================] - 3s 81ms/step - loss: 0.0028
# Epoch 54/100
# 38/38 [==============================] - 3s 83ms/step - loss: 0.0023
# Epoch 55/100
# 38/38 [==============================] - 3s 81ms/step - loss: 0.0024
# Epoch 56/100
# 38/38 [==============================] - 3s 82ms/step - loss: 0.0028
# Epoch 57/100
# 38/38 [==============================] - 3s 76ms/step - loss: 0.0027
# Epoch 58/100
# 38/38 [==============================] - 3s 78ms/step - loss: 0.0022
# Epoch 59/100
# 38/38 [==============================] - 3s 78ms/step - loss: 0.0028
# Epoch 60/100
# 38/38 [==============================] - 3s 79ms/step - loss: 0.0022
# Epoch 61/100
# 38/38 [==============================] - 3s 81ms/step - loss: 0.0023
# Epoch 62/100
# 38/38 [==============================] - 3s 78ms/step - loss: 0.0022
# Epoch 63/100
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0023
# Epoch 64/100
# 38/38 [==============================] - 3s 83ms/step - loss: 0.0024
# Epoch 65/100
# 38/38 [==============================] - 3s 83ms/step - loss: 0.0022
# Epoch 66/100
# 38/38 [==============================] - 3s 83ms/step - loss: 0.0021
# Epoch 67/100
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0021
# Epoch 68/100
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0022
# Epoch 69/100
# 38/38 [==============================] - 3s 81ms/step - loss: 0.0023
# Epoch 70/100
# 38/38 [==============================] - 3s 86ms/step - loss: 0.0019
# Epoch 71/100
# 38/38 [==============================] - 3s 75ms/step - loss: 0.0021
# Epoch 72/100
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0021
# Epoch 73/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.0022
# Epoch 74/100
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0023
# Epoch 75/100
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0020
# Epoch 76/100
# 38/38 [==============================] - 3s 82ms/step - loss: 0.0020
# Epoch 77/100
# 38/38 [==============================] - 3s 82ms/step - loss: 0.0021
# Epoch 78/100
# 38/38 [==============================] - 3s 86ms/step - loss: 0.0020
# Epoch 79/100
# 38/38 [==============================] - 3s 78ms/step - loss: 0.0023
# Epoch 80/100
# 38/38 [==============================] - 3s 78ms/step - loss: 0.0018
# Epoch 81/100
# 38/38 [==============================] - 3s 78ms/step - loss: 0.0018
# Epoch 82/100
# 38/38 [==============================] - 3s 75ms/step - loss: 0.0017
# Epoch 83/100
# 38/38 [==============================] - 3s 75ms/step - loss: 0.0020
# Epoch 84/100
# 38/38 [==============================] - 3s 76ms/step - loss: 0.0018
# Epoch 85/100
# 38/38 [==============================] - 3s 75ms/step - loss: 0.0019
# Epoch 86/100
# 38/38 [==============================] - 3s 78ms/step - loss: 0.0015
# Epoch 87/100
# 38/38 [==============================] - 3s 81ms/step - loss: 0.0017
# Epoch 88/100
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0018
# Epoch 89/100
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0018
# Epoch 90/100
# 38/38 [==============================] - 3s 82ms/step - loss: 0.0019
# Epoch 91/100
# 38/38 [==============================] - 3s 81ms/step - loss: 0.0016
# Epoch 92/100
# 38/38 [==============================] - 3s 83ms/step - loss: 0.0016
# Epoch 93/100
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0016
# Epoch 94/100
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0017
# Epoch 95/100
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0017
# Epoch 96/100
# 38/38 [==============================] - 3s 86ms/step - loss: 0.0015
# Epoch 97/100
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0015
# Epoch 98/100
# 38/38 [==============================] - 3s 86ms/step - loss: 0.0014
# Epoch 99/100
# 38/38 [==============================] - 3s 86ms/step - loss: 0.0017
# Epoch 100/100
# 38/38 [==============================] - 3s 84ms/step - loss: 0.0018

# %%
regressor_large_time_scale.fit(x_train_data, y_train_data, epochs=250, batch_size=8)
regressor_large_time_scale.save('models/google_stock_price_prediction_lstm_large_time_scale.h5')
# Out:
# Epoch 1/250
# 150/150 [==============================] - 17s 66ms/step - loss: 0.0182
# Epoch 2/250
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0061
# Epoch 3/250
# 150/150 [==============================] - 10s 64ms/step - loss: 0.0057
# Epoch 4/250
# 150/150 [==============================] - 10s 65ms/step - loss: 0.0062
# Epoch 5/250
# 150/150 [==============================] - 9s 62ms/step - loss: 0.0046
# Epoch 6/250
# 150/150 [==============================] - 9s 61ms/step - loss: 0.0044
# Epoch 7/250
# 150/150 [==============================] - 10s 64ms/step - loss: 0.0045
# Epoch 8/250
# 150/150 [==============================] - 10s 68ms/step - loss: 0.0039
# Epoch 9/250
# 150/150 [==============================] - 12s 77ms/step - loss: 0.0034
# Epoch 10/250
# 150/150 [==============================] - 10s 66ms/step - loss: 0.0037
# Epoch 11/250
# 150/150 [==============================] - 10s 68ms/step - loss: 0.0038
# Epoch 12/250
# 150/150 [==============================] - 10s 68ms/step - loss: 0.0041
# Epoch 13/250
# 150/150 [==============================] - 10s 68ms/step - loss: 0.0033
# Epoch 14/250
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0028
# Epoch 15/250
# 150/150 [==============================] - 14s 93ms/step - loss: 0.0031
# Epoch 16/250
# 150/150 [==============================] - 13s 89ms/step - loss: 0.0032
# Epoch 17/250
# 150/150 [==============================] - 14s 92ms/step - loss: 0.0030
# Epoch 18/250
# 150/150 [==============================] - 13s 87ms/step - loss: 0.0029
# Epoch 19/250
# 150/150 [==============================] - 14s 90ms/step - loss: 0.0027
# Epoch 20/250
# 150/150 [==============================] - 14s 91ms/step - loss: 0.0026
# Epoch 21/250
# 150/150 [==============================] - 13s 88ms/step - loss: 0.0026
# Epoch 22/250
# 150/150 [==============================] - 13s 88ms/step - loss: 0.0025
# Epoch 23/250
# 150/150 [==============================] - 13s 87ms/step - loss: 0.0024
# Epoch 24/250
# 150/150 [==============================] - 13s 89ms/step - loss: 0.0025
# Epoch 25/250
# 150/150 [==============================] - 13s 88ms/step - loss: 0.0021
# Epoch 26/250
# 150/150 [==============================] - 13s 88ms/step - loss: 0.0022
# Epoch 27/250
# 150/150 [==============================] - 13s 89ms/step - loss: 0.0023
# Epoch 28/250
# 150/150 [==============================] - 13s 88ms/step - loss: 0.0020
# Epoch 29/250
# 150/150 [==============================] - 13s 88ms/step - loss: 0.
# 150/150 [==============================] - 15s 100ms/step - loss: 9.5887e-04
# Epoch 240/250
# 150/150 [==============================] - 14s 94ms/step - loss: 8.9032e-04
# Epoch 241/250
# 150/150 [==============================] - 14s 93ms/step - loss: 8.9783e-04
# Epoch 242/250
# 150/150 [==============================] - 14s 93ms/step - loss: 8.3924e-04
# Epoch 243/250
# 150/150 [==============================] - 14s 94ms/step - loss: 9.7639e-04
# Epoch 244/250
# 150/150 [==============================] - 14s 93ms/step - loss: 9.0230e-04
# Epoch 245/250
# 150/150 [==============================] - 14s 93ms/step - loss: 7.9928e-04
# Epoch 246/250
# 150/150 [==============================] - 14s 94ms/step - loss: 8.6839e-04
# Epoch 247/250
# 150/150 [==============================] - 14s 94ms/step - loss: 8.1047e-04
# Epoch 248/250
# 150/150 [==============================] - 14s 93ms/step - loss: 8.9418e-04
# Epoch 249/250
# 150/150 [==============================] - 14s 93ms/step - loss: 8.9144e-04
# Epoch 250/250
# 150/150 [==============================] - 14s 93ms/step - loss: 0.0010

# %% [markdown]
# ### 11. Import the testing data set

# %%
test_df = pd.read_csv('dataset/Google_Stock_Price_Test.csv')
test_df.head()
# Out:
#        Date    Open    High     Low   Close     Volume
# 0  1/3/2017  778.81  789.63  775.80  786.14  1,657,300
# 1  1/4/2017  788.36  791.34  783.16  786.90  1,073,000
# 2  1/5/2017  786.08  794.48  785.02  794.02  1,335,200
# 3  1/6/2017  795.26  807.90  792.20  806.15  1,640,200
# 4  1/9/2017  806.40  809.97  802.83  806.65  1,272,400

# %% [markdown]
# ### 12. Data processing

# %%
test_data = test_df.sort_index(ascending=True, axis=0)
test_data = test_data.iloc[:, [1]]

test_data_value = test_data.values

total_data = pd.concat((train_df['Open'], test_df['Open']), axis=0)

# %% [markdown]
# ### 13. Prepare inputs for prediction

# %%
inputs = total_data[len(total_data) - len(test_data) - 60:].values

# %% [markdown]
# ### 14. Normalize and create the data structure

# %%
inputs = inputs.reshape(-1,1)

inputs = scaler.transform(inputs)

x_test_data = []
for i in range(60, len(inputs)):
    x_test_data.append(inputs[i-60:i, 0])

x_test_data = np.array(x_test_data)
x_test_data = np.reshape(x_test_data, (x_test_data.shape[0], x_test_data.shape[1], 1))

# %% [markdown]
# ### 15. Predict the stock price using the LSTM model

# %%
predicted_stock_price = regressor.predict(x_test_data)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
predicted_stock_price_large_time_scale = regressor_large_time_scale.predict(x_test_data)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %% [markdown]
# ### 16. Invert the scaling of the predicted stock price

# %%
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

# %%
predicted_stock_price_large_time_scale = scaler.inverse_transform(predicted_stock_price_large_time_scale)

# %%
plt.plot(test_data_value, color='red', label='Real Google Stock Price')
plt.plot(predicted_stock_price, color='blue', label='Predicted Google Stock Price')

plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')

plt.legend()
plt.show()

# %%
plt.plot(test_data_value, color='red', label='Real Google Stock Price Large Scale')
plt.plot(predicted_stock_price_large_time_scale, color='blue', label='Predicted Google Stock Price')

plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')

plt.legend()
plt.show()
